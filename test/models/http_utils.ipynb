# %%
import json
from planner.models.groups import Course
from planner.parsing.parse_elements import group_factory

# %%
def load_from_file(file: str):
    with open(file, encoding='utf-8') as f:
        return json.load(f)

# %%
file_name = '../../data/courses.json'

# %%
json_loaded = load_from_file(file_name)

# %%
courses = [Course(groups=[group_factory(**group) for group in loaded_course['groups']],
        **{attr : loaded_course[attr] for attr in loaded_course if attr != 'groups'})
 for loaded_course in json_loaded['courses']]

# %%
courses
# Out:
# [Course(name='Bazy danych', code='INZ002007C', groups=[Group(code='K01-17a', course='INZ002007C', lecturer=Dr hab. Zygmunt Mazur, day=<DayOfWeek.Monday: 1>, week_type=<WeekType.ODD_WEEK: 3>, start_time=datetime.datetime(1900, 1, 1, 9, 15), end_time=datetime.datetime(1900, 1, 1, 11, 0), building='D-1', hall='311c', type=<GroupType.PRACTICALS: 2>), Group(code='K01-17b', course='INZ002007C', lecturer=Dr hab. Zygmunt Mazur, day=<DayOfWeek.Monday: 1>, week_type=<WeekType.EVEN_WEEK: 2>, start_time=datetime.datetime(1900, 1, 1, 9, 15), end_time=datetime.datetime(1900, 1, 1, 11, 0), building='D-1', hall='311c', type=<GroupType.PRACTICALS: 2>), Group(code='K01-17c', course='INZ002007C', lecturer=Dr hab. Zygmunt Mazur, day=<DayOfWeek.Tuesday: 2>, week_type=<WeekType.ODD_WEEK: 3>, start_time=datetime.datetime(1900, 1, 1, 9, 15), end_time=datetime.datetime(1900, 1, 1, 11, 0), building='D-1', hall='311c', type=<GroupType.PRACTICALS: 2>), Group(code='K01-17e', course='INZ002007C', lecturer=Dr hab.
# ...

# %%
from planner.parsing.parse_json import load_from_json
file_name = '../../data/courses.json'
courses = load_from_json(file_name)

# %%
courses
# Out:
# [Course(name='Bazy danych', code='INZ002007C', groups=[Group(code='K01-17a', course='INZ002007C', lecturer=Dr hab. Zygmunt Mazur, day=<DayOfWeek.Monday: 1>, week_type=<WeekType.ODD_WEEK: 3>, start_time=datetime.datetime(1900, 1, 1, 9, 15), end_time=datetime.datetime(1900, 1, 1, 11, 0), building='D-1', hall='311c', type=<GroupType.PRACTICALS: 2>), Group(code='K01-17b', course='INZ002007C', lecturer=Dr hab. Zygmunt Mazur, day=<DayOfWeek.Monday: 1>, week_type=<WeekType.EVEN_WEEK: 2>, start_time=datetime.datetime(1900, 1, 1, 9, 15), end_time=datetime.datetime(1900, 1, 1, 11, 0), building='D-1', hall='311c', type=<GroupType.PRACTICALS: 2>), Group(code='K01-17c', course='INZ002007C', lecturer=Dr hab. Zygmunt Mazur, day=<DayOfWeek.Tuesday: 2>, week_type=<WeekType.ODD_WEEK: 3>, start_time=datetime.datetime(1900, 1, 1, 9, 15), end_time=datetime.datetime(1900, 1, 1, 11, 0), building='D-1', hall='311c', type=<GroupType.PRACTICALS: 2>), Group(code='K01-17e', course='INZ002007C', lecturer=Dr hab.
# ...
